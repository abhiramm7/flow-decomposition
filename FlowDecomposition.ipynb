# %%
import numpy as np
import scipy as spi
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
t = np.linspace(0.0, 20.0, 200)
baseflow = 2.0 * np.exp(-t)
diurnal = 0.75 * np.sin(0.3*t*np.pi) + 0.50
signal = baseflow + diurnal

# %%
plt.figure(figsize=(10, 5))
plt.plot(t, signal)
plt.ylabel("Flow cu.ft per sec")
# Out:
# Text(0, 0.5, 'Flow cu.ft per sec')

# %%
BFI = 0.001
a = 0.001

# %%
for i in range(0, len(signal)):
    bk
